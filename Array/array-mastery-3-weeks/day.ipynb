# %%
import os

week2_base = "Week 2 - Sliding Window, Kadane’s, Hashing"
day_folders = [
    {
        "name": "Day 8 - Sliding Window (Fixed Size)",
        "files": [
            ("max_sum_subarray_k.py", """
Max Sum Subarray of Size K

Problem:
Given an array of positive numbers and a number `k`, find the maximum sum of any contiguous subarray of size `k`.

Input: [2, 1, 5, 1, 3, 2], k = 3
Output: 9  # Subarray: [5,1,3]
"""),
            ("average_subarrays_k.py", """
Average of All Subarrays of Size K

Problem:
Print the average of all contiguous subarrays of size `k` in a given array.

Input: [1, 3, 2, 6, -1, 4, 1, 8, 2], k = 5
Output: [2.2, 2.8, 2.4, 3.6, 4.0]
"""),
            ("max_sum_k_with_negatives.py", """
Max Sum Subarray of Size K (with Negatives)

Problem:
Given an array that may contain negative numbers, find the maximum sum of any contiguous subarray of size `k`.

Input: [4, -2, -8, 5, -2, 7, 7, 2, -6, 5], k = 4
Output: 17  # Subarray: [5, -2, 7, 7]
"""),
        ]
    },
    {
        "name": "Day 9 - Sliding Window (Variable Size)",
        "files": [
            ("smallest_subarray_with_sum.py", """
Smallest Subarray With Sum >= Target

Problem:
Given an array of positive numbers and a positive number `target`, find the length of the smallest contiguous subarray whose sum is >= target. Return 0 if no such subarray exists.

Input: [2, 1, 5, 2, 3, 2], target = 7
Output: 2  # Subarray: [5,2]
"""),
            ("longest_subarray_with_sum_at_most_k.py", """
Longest Subarray With Sum <= K

Problem:
Given an array and a number `k`, return the length of the longest subarray whose sum is less than or equal to `k`.

Input: [1, 2, 1, 0, 1], k = 4
Output: 4  # Subarray: [1,2,1,0]
"""),
            ("longest_subarray_with_sum_exact_k.py", """
Longest Subarray With Sum == K

Problem:
Find the longest contiguous subarray that sums exactly to `k`.

Input: [1, 2, 3, 1, 1, 1], k = 6
Output: 3  # Subarray: [3,1,1,1]
"""),
        ]
    }
    # You can extend this list similarly for Day 10 to Day 14
]

for day in day_folders:
    base_path = os.path.join(week2_base, day["name"])
    code_path = os.path.join(base_path, "code")
    os.makedirs(code_path, exist_ok=True)

    # Create worksheet.md
    with open(os.path.join(base_path, "worksheet.md"), "w", encoding="utf-8") as f:
        f.write(f"# {day['name']}\n\n## Topics\n- Review worksheet for {day['name'].split('-')[1].strip()}\n- Solve 3 real-world coding problems\n\n---\n\n## Coding Questions\n")
        for file in day["files"]:
            f.write(f"\n### {file[0]}\nFilename: `code/{file[0]}`\n\n---\n")

    # Create code files
    for filename, docstring in day["files"]:
        with open(os.path.join(code_path, filename), "w", encoding="utf-8") as f:
            f.write(docstring)
